# %% [markdown]
# # LangChain v1

# %% [markdown]
# ## 1. 概述 Overview

# %% [markdown]
# LangChain 是构建基于 LLM 的智能体和应用程序的最简便方法。只需不到 10 行代码，即可连接到 OpenAI、Anthropic、Google 等平台。LangChain 提供预构建的智能体架构和模型集成，帮助您快速上手，并将 LLM 无缝集成到您的智能体和应用程序中。
#
# 如果您希望快速构建代理和自主应用程序，我们推荐您使用 LangChain。如果您有更高级的需求，需要结合确定性工作流和代理工作流、高度定制化以及严格控制延迟，则可以使用我们的底层代理编排框架和运行时 LangGraph。
#
# LangChain代理构建于LangGraph之上，旨在提供持久执行、流式处理、人机交互、持久化等功能。您无需了解LangGraph即可使用LangChain代理的基本功能。
#
#
# 官方文档：[LangChain overview - Docs by LangChain](https://docs.langchain.com/oss/python/langchain/overview)

# %% [markdown]
# ## 2. 发行说明 Release notes

# %% [markdown]
# [What's new in v1 - Docs by LangChain](https://docs.langchain.com/oss/python/releases/langchain-v1)
#
# **LangChain v1 是一个专注的、可用于生产的构建代理的基础。** 围绕三个核心改进简化了框架：
#
# - create_agent
# - Standard content blocks
# - Simplified package

# %% [markdown]
# ## 3. 迁移指南 Migration guide
#
# 概述了 LangChain v1 与先前版本之间的主要变化
#
# [LangChain v1 migration guide - Docs by LangChain](https://docs.langchain.com/oss/python/migrate/langchain-v1)
#
# - Simplified package
# - Migrate to `create_agent`
# - Standard content

# %% [markdown]
# ## 4. 核心组件 Core components

# %% [markdown]
# - Agents
# - Models
# - Messages
# - Tools
# - Short-term memory
# - Streaming
# - Structured output

# %% [markdown]
# ## 5. 中间件 Middleware

# %% [markdown]
# 中间件提供了一种更严格地控制代理内部运行机制的方法。中间件的用途包括：
#
# - 通过日志记录、分析和调试来跟踪代理行为。
# - 转换提示、工具选择和输出格式。
# - 添加重试、回退和提前终止逻辑。
# - 应用速率限制、防护措施和个人身份信息检测。
#
# <img src="./assets/middleware_final.avif">
#
# 中间件类型：
# - 内置中间件
# - 自定义中间件

# %% [markdown]
# ## 6. 高级用法

# %% [markdown]
# - Guardrails
# - Runtime
# - Context engineering in agents
# - Model Context Protocol (MCP)
# - Human-in-the-loop
# - Multi-agent
# - Retrieval
# - Long-term memory

# %% [markdown]
# ## 附录：运行课堂实验

# %% [markdown]
# 1. 下载课件，解压到一个非中文的目录
# 2. 创建 conda 环境 `langchain-v1-notebook`
#    ```bash
#    conda create -n langchain-v1-notebook python=3.11 ipykernel
#    conda activate langchain-v1-notebook
#    ```
# 3. 安装相关依赖包
#    ```bash
#    pip install jupyterlab
#    pip install -U langchain
#    pip install langchain-community
#    pip install langchain-mcp-adapters
#    pip install markdownify
#    ...
#    ```
# 4. 运行演示
#    ```bash
#    > cd langchain-v1-notebook
#    > jupyter lab
#    ```
